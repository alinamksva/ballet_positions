# %%
import os
import matplotlib.pyplot as plt
from pprint import pprint

# %%
from google.colab import drive
drive.mount('/content/drive')

zip_file_name = ''
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_file_name = ''

with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall()

# %%
labels_path = '/content/dataset┬áΓÇö ╨║╨╛╨┐╨╕╤Å/legs_positions_labels'
pics_path = '/content/dataset┬áΓÇö ╨║╨╛╨┐╨╕╤Å/legs_positions_pictures'

# %%
folder_counts = {}

# %%
for folder in os.listdir(pics_path):
    folder_path = os.path.join(pics_path, folder)

    if os.path.isdir(folder_path):
        image_count = sum(1 for file in os.listdir(folder_path) if file.lower().endswith(('.png', '.jpg', '.jpeg')))
        folder_counts[folder] = image_count

# %%
pprint(folder_counts)
# Out:
# {'arabesque_1': 261,
#  'arabesque_2': 22,
#  'arabesque_3': 17,
#  'arabesque_4': 13,
#  'arabesque_penchee': 21,
#  'attitude_croisee_derriere': 36,
#  'attitude_croisee_devant': 25,
#  'attitude_effacee_derriere': 228,
#  'attitude_effacee_devant': 2,
#  'brise_vole': 29,
#  'croisee_derriere': 101,
#  'croisee_devant': 56,
#  'ecarte_derriere': 2,
#  'ecarte_devant': 68,
#  'effacee_derriere': 61,
#  'effacee_devant': 8,
#  'grand_battement_a_la_seconde': 247,
#  'grand_battement_devant': 41,
#  'grand_jete': 185,
#  'grand_plie': 98,
#  'pas_de_chat': 44,
#  'quatrieme_derriere': 19,
#  'quatrieme_devant': 3,
#  'releve': 59,
#  'retire': 142,
#  'sissonne': 69,
#  'sissonne_attitude': 42,
#  'sissonne_soubresaut': 52,
#  'sur_le_cou_de_pied_de_cote': 4}

# %%
print(f'Количество классов: {len(folder_counts)}')
# Out:
# Количество классов: 29

# %%
plt.figure(figsize=(10, 6))
plt.bar(folder_counts.keys(), folder_counts.values(), color='lightpink')

plt.xlabel("Позиции", fontsize=12)
plt.ylabel("Количество картинок", fontsize=12)
plt.title("Распредение по классам", fontsize=14)
plt.xticks(rotation=45, ha="right")
plt.show()
